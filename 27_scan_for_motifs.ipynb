# %%
# The partial escape hatch, as before: sequence-based domain detection (run HMMER/ELM directly on the exon peptide) sidesteps coordinates — a match is a match regardless of numbering. But position-based cross-referencing (UniProt features, mapping full-protein InterProScan hits onto exons, isoform diffs) genuinely needs a correct, shared Met1.
